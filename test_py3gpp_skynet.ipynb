# %%
import numpy as np
import sigmf
import scipy
import matplotlib.pyplot as plt
from py3gpp import *
from data_path import data_path

# %%
# handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_10.sigmf-data')
# skynet_tx_stream_3: good CFO, bad STO
# skynet_tx_stream_3: good CFO, good STO, CRC ok
# skynet_tx_hdl: good CFO, good STO
# handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_hdl_4.sigmf-data')
# handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_hdl_good_cfo.sigmf-data')  # with PDSCH DMRS power boost
# handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_hdl_good_cfo_new_seq3.sigmf-data')  # with PDSCH DMRS power boost
# handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_stream_3.sigmf-data')
# handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_stream_generic.sigmf-data')
handle = sigmf.sigmffile.fromfile(data_path + '/skynet_tx_hdl_generic.sigmf-data')
delta_f = 0
f = 1
mu = 0
apply_fine_CFO = 0

waveform = handle.read_samples()
waveform /= max(waveform.real.max(), waveform.imag.max()) # scale max amplitude to 1
fs = handle.get_global_field(sigmf.SigMFFile.SAMPLE_RATE_KEY)
print(fs)
# Out:
# 7680010.0

# %%
waveform =  waveform * np.exp(-1j*2*np.pi*delta_f/fs*(np.arange(len(waveform))))

# %%
N_PRB = 25
FFT_LEN = N_PRB * 12
carrier = nrCarrierConfig(NSizeGrid = N_PRB, SubcarrierSpacing = 15 * 2**mu)
info = nrOFDMInfo(carrier)
Nfft = info['Nfft']

peak_value = np.zeros(3)
peak_index = np.zeros(3, 'int')
pssIndices = np.arange((FFT_LEN // 2 - 1 - 63), (FFT_LEN // 2 - 1 + 64))
fig, axs = plt.subplots(3, 1, facecolor='w', sharex=True, sharey=True)
for current_NID2 in np.arange(3, dtype='int'):
    slotGrid = nrResourceGrid(carrier)
    slotGrid = slotGrid[:, 0]
    slotGrid[pssIndices] = (nrPSS(current_NID2))
    [refWaveform, info] = nrOFDMModulate(carrier, slotGrid, SampleRate = fs)
    refWaveform = refWaveform[info['CyclicPrefixLengths'][0]:]; # remove CP

    temp = scipy.signal.correlate(waveform[:int(45e-3 * fs)], refWaveform, 'valid')  # correlate over 25 ms
    peak_index[current_NID2] = np.argmax(np.abs(temp))
    peak_value[current_NID2] = np.abs(temp[peak_index[current_NID2]])
    t_corr = np.arange(temp.shape[0])/fs*1e3
    axs[current_NID2].plot(t_corr, np.abs(temp))
detected_NID2 = np.argmax(peak_value)
print(f'detected NID2 is {detected_NID2}')
# Out:
# detected NID2 is 0

# %%
nrbSSB = 20
scsSSB = 15 * 2**(mu)
nSlot = 1
rxSampleRate = fs
if False:
    cp1 = np.round(5.2e-6*fs * 2**(-mu))
    cp2 = np.round(4.7e-6*fs * 2**(-mu))
    timingOffset = int(35264 - 2048 - cp1 - cp2)
else:
    nrbSSB = 20
    refGrid = np.zeros((nrbSSB*12, 2), np.complex128)
    refGrid[nrPSSIndices(), 1] = nrPSS(detected_NID2)
    timingOffset = nrTimingEstimate(waveform = waveform, nrb = nrbSSB, scs = scsSSB, initialNSlot = nSlot, refGrid = refGrid, SampleRate = rxSampleRate)

# %%
x0 = max(0, timingOffset - 1E-3*fs) # display 1 ms before detected PSS
plt.specgram(waveform[int(x0):int(x0)+Nfft*100], Fs=fs, NFFT=Nfft, noverlap=0)
a0_time = (timingOffset-x0)/fs
plt.axvline(x = a0_time, color = 'b', label = 'axvline - full height')

# %%
# modulate about 8 symbols, only has to be at least 5
nSlot = 1
rxGrid = nrOFDMDemodulate(waveform = waveform[timingOffset:][:np.min((len(waveform), 2048*8))], nrb = nrbSSB, scs = scsSSB, initialNSlot = nSlot, SampleRate=rxSampleRate, CyclicPrefixFraction=0.5)
rxGrid = rxGrid[:,1:5]
rxGrid /= np.max((rxGrid.real.max(), rxGrid.imag.max()))

# %%
sssIndices = nrSSSIndices()
sssRx = nrExtractResources(sssIndices, rxGrid)
sssRx /= np.max((sssRx.real.max(), sssRx.imag.max())) # scale sssRx symbols individually

fig, axs = plt.subplots(1, 1, figsize=(5, 5), facecolor='w', sharex=True, sharey=True)
axs.plot(sssRx.real, sssRx.imag, '.')
axs.add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs.set_xticks([])
axs.set_yticks([])
        
fig.subplots_adjust(hspace=0, wspace=0)
fig.suptitle('SSS symbols', y=0.95)
# Out:
# Text(0.5, 0.95, 'SSS symbols')

# %%
sssEst = np.zeros(336)
for NID1 in range(335):
    ncellid = (3*NID1) + detected_NID2
    sssRef = nrSSS(ncellid)
    sssEst[NID1] = np.abs(np.vdot(sssRx, sssRef))

detected_NID1 = np.argmax(sssEst)
detected_NID = detected_NID1*3 + detected_NID2
print(f'detected NID1 is {detected_NID1}')
print(f'detected NID is {detected_NID}')
plt.plot(sssEst)
plt.show()
# Out:
# detected NID1 is 0
# detected NID is 0

# %%
dmrsIndices = nrPBCHDMRSIndices(detected_NID, style='matlab')
xcorrPBCHDMRS = np.empty(7)
for ibar_SSB in range(7):
    PBCHDMRS = nrPBCHDMRS(detected_NID, ibar_SSB)
    xcorrPBCHDMRS[ibar_SSB] = np.abs(np.vdot(nrExtractResources(dmrsIndices, rxGrid), PBCHDMRS))
ibar_SSB = np.argmax(np.abs(xcorrPBCHDMRS))

plt.plot(np.abs(xcorrPBCHDMRS))
plt.title('PBCH correlations for different ibar_SSB')
plt.show()
print(f'ibar_SSB is {ibar_SSB}')
# Out:
# ibar_SSB is 0

# %%
refGrid = np.zeros((nrbSSB*12, 4), 'complex')
dmrsIndices = nrPBCHDMRSIndices(detected_NID)

if False:
    refGridFlat = refGrid.ravel(order='F')
    refGridFlat[dmrsIndices] = nrPBCHDMRS(detected_NID, ibar_SSB)
    refGrid = refGridFlat.reshape(refGrid.shape, order='F')

    refGridFlat = refGrid.ravel(order='F')
    refGridFlat[sssIndices] = nrSSS(detected_NID)
    refGrid = refGridFlat.reshape(refGrid.shape, order='F')
else:
    nrSetResources(dmrsIndices, refGrid, nrPBCHDMRS(detected_NID, ibar_SSB))

# %%
PBCHDMRS_wiped = nrExtractResources(dmrsIndices, rxGrid) / nrExtractResources(dmrsIndices, refGrid)

fig, axs = plt.subplots(1, 1, figsize=(5, 5), facecolor='w', sharex=True, sharey=True)
axs.plot(PBCHDMRS_wiped.real, PBCHDMRS_wiped.imag, '.')
axs.add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs.set_xticks([])
axs.set_yticks([])
        
fig.subplots_adjust(hspace=0, wspace=0)
fig.suptitle('wiped PBCHDMRS symbols', y=0.95)
# Out:
# Text(0.5, 0.95, 'wiped PBCHDMRS symbols')

# %%
import matplotlib.patches as mpatches 
H, nVar = nrChannelEstimate(rxGrid = rxGrid, refGrid = refGrid)
im = plt.imshow(np.abs(H), origin='lower', aspect='auto')
values = np.linspace(np.min(np.abs(H)), np.max(np.abs(H)), 10)
colors = [ im.cmap(im.norm(value)) for value in values]
patches = [ mpatches.Patch(color=colors[i], label="Level {l}".format(l=values[i]) ) for i in range(len(values))]
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

im = plt.imshow(np.angle(H), origin='lower', aspect='auto')
values = np.linspace(np.min(np.angle(H)), np.max(np.angle(H)), 10)
colors = [ im.cmap(im.norm(value)) for value in values]
patches = [ mpatches.Patch(color=colors[i], label="Level {l}".format(l=values[i]) ) for i in range(len(values))]
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
PBCHDMRS_wiped = nrExtractResources(dmrsIndices, rxGrid/H)

fig, axs = plt.subplots(1, 1, figsize=(5, 5), facecolor='w', sharex=True, sharey=True)
axs.plot(PBCHDMRS_wiped.real, PBCHDMRS_wiped.imag, '.')
axs.add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs.set_xticks([])
axs.set_yticks([])
        
fig.subplots_adjust(hspace=0, wspace=0)
fig.suptitle('equilized PBCHDMRS symbols', y=0.95)
# Out:
# Text(0.5, 0.95, 'equilized PBCHDMRS symbols')

# %%
pbchIndices = nrPBCHIndices(detected_NID)
# rxGrid[pbchIndices[90] - 240, 1] = 0
pbch_eqed, csi = nrEqualizeMMSE(nrExtractResources(pbchIndices, rxGrid), nrExtractResources(pbchIndices, H), nVar)
pbch_syms = nrExtractResources(pbchIndices, rxGrid)
# for i in range(len(pbchIndices)):
#     print(f'{i} {pbchIndices[i]} {pbch_syms[i]}')

fig, axs = plt.subplots(1, 3, figsize=(15, 5), facecolor='w', sharex=True, sharey=True)
pbch_sel = pbch_eqed[0:180]
axs[0].plot(pbch_sel.real, pbch_sel.imag, '.')
axs[0].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs[0].set_xticks([])
axs[0].set_yticks([])
axs[0].set_title('sym 0')

pbch_sel = pbch_eqed[180:][:72]
axs[1].plot(pbch_sel.real, pbch_sel.imag, '.')
axs[1].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs[1].set_xticks([])
axs[1].set_yticks([])
axs[1].set_title('sym 1')

pbch_sel = pbch_eqed[180+72:]
axs[2].plot(pbch_sel.real, pbch_sel.imag, '.')
axs[2].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs[2].set_xticks([])
axs[2].set_yticks([])
axs[2].set_title('sym 2')


fig.subplots_adjust(hspace=0, wspace=0)
fig.suptitle('equilized PBCH symbols', y=0.95)
# Out:
# Text(0.5, 0.95, 'equilized PBCH symbols')

# %%
pbchBits = nrSymbolDemodulate(pbch_eqed, 'QPSK', nVar, 'soft')
pbchBits_hard = nrSymbolDemodulate(pbch_eqed, 'QPSK', nVar, 'hard')
np.savetxt('pbch_bits.txt', pbchBits_hard.astype(int), fmt='%1d')
E = 864
v = ibar_SSB
scrambling_seq = nrPBCHPRBS(detected_NID, v, E)
scrambling_seq_bpsk = (-1)*scrambling_seq*2 + 1
pbchBits_descrambled = pbchBits * scrambling_seq_bpsk
pbchBits_csi = pbchBits_descrambled * np.repeat(csi, 2)

A = 32
P = 24
K = A+P
N = 512 # calculated according to Section 5.3.1 of 3GPP TS 38.212
decIn = nrRateRecoverPolar(pbchBits_csi, K, N, False, discardRepetition=False)

# values from Matlab
decoded = nrPolarDecode(decIn, K, 0, 0)

# check CRC
decoded3, crc_result = nrCRCDecode(decoded, '24C')
if crc_result == 0:
    print("nrPolarDecode: PBCH CRC ok")
else:
    print("nrPolarDecode: PBCH CRC failed")
# Out:
# nrPolarDecode: PBCH CRC ok

# %%
# demodulate 2 subframes
rxGrid = nrOFDMDemodulate(waveform = waveform[timingOffset:][:np.min((len(waveform), Nfft*200))], nrb = carrier.NSizeGrid, scs = scsSSB, initialNSlot = 1, SampleRate=rxSampleRate, CyclicPrefixFraction=0.5)
rxGrid = rxGrid[:,13:13+14]
rxGrid /= np.max((rxGrid.real.max(), rxGrid.imag.max()))

# %%
# %matplotlib wx 
plt.imshow(np.abs(rxGrid[:,:14]), aspect = 'auto', origin='lower')
plt.axvline(x = a0_time, color = 'b', label = 'axvline - full height')
plt.show()

# %%
# extract PDSCH DMRS and plot correlation
pdsch_cfg = nrPDSCHConfig()
pdsch_cfg.NSizeBWP = carrier.NSizeGrid
pdsch_cfg.NStartBWP = 0
pdsch_cfg.MappingType = 'A'
pdsch_cfg.DMRS.DMRSTypeAPosition = 2
pdsch_cfg.DMRS.DMRSLength = 1
pdsch_cfg.DMRS.DMRSAdditionalPosition = 2
pdsch_cfg.DMRS.DMRSConfigurationType = 1
pdsch_cfg.DMRS.NIDNSCID = 0
pdsch_cfg.DMRS.NSCID = 0
pdsch_cfg.PRBSet = list(range(0, carrier.NSizeGrid))
pdsch_cfg.SymbolAllocation = [0, 14]
dmrsIndices = nrPDSCHDMRSIndices(carrier, pdsch_cfg)

dmrs_rx = nrExtractResources(dmrsIndices, rxGrid)

fig, axs = plt.subplots(1, 3, figsize=(15, 5), facecolor='w', sharex=True, sharey=True)
samples = dmrs_rx[0:150]
axs[0].plot(samples.real, samples.imag, '.')
axs[0].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs[0].set_xticks([])
axs[0].set_yticks([])
axs[0].set_title('sym 2')

samples = dmrs_rx[150:][:150]
axs[1].plot(samples.real, samples.imag, '.')
axs[1].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs[1].set_xticks([])
axs[1].set_yticks([])
axs[1].set_title('sym 7')

samples = dmrs_rx[300:][:150]
axs[2].plot(samples.real, samples.imag, '.')
axs[2].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs[2].set_xticks([])
axs[2].set_yticks([])
axs[2].set_title('sym 11')
# Out:
# Text(0.5, 1.0, 'sym 11')

# %%
carrier.NSlot = 1
dmrs_ideal = nrPDSCHDMRS(pdsch_cfg, carrier)
print(np.abs(np.vdot(dmrs_rx, dmrs_ideal)))

refGrid = np.zeros((carrier.NSizeGrid * 12, 14), 'complex')
nrSetResources(dmrsIndices, refGrid, dmrs_ideal)

import matplotlib.patches as mpatches
H, nVar = nrChannelEstimate(rxGrid = rxGrid, refGrid = np.sqrt(2)*refGrid)
print(f'nVar = {nVar}')

if False:
    # low pass filter H
    from PIL import Image, ImageDraw
    from scipy import fftpack
    fft1 = fftpack.fftshift(fftpack.fft2(H))
    x,y = H.shape[0],H.shape[1]
    e_x,e_y=x//10, y//10
    bbox=((x/2)-(e_x/2),(y/2)-(e_y/2),(x/2)+(e_x/2),(y/2)+(e_y/2))
    low_pass=Image.new("L",(H.shape[0],H.shape[1]),color=0)
    draw1=ImageDraw.Draw(low_pass)
    draw1.ellipse(bbox, fill=1)
    low_pass_np=np.array(low_pass)
    filtered=np.multiply(fft1,low_pass_np.T)
    H = np.real(fftpack.ifft2(fftpack.ifftshift(filtered)))

im = plt.imshow(np.abs(H), origin='lower', aspect='auto')
values = np.linspace(np.min(np.abs(H)), np.max(np.abs(H)), 10)
colors = [ im.cmap(im.norm(value)) for value in values]
patches = [ mpatches.Patch(color=colors[i], label="Level {l}".format(l=values[i]) ) for i in range(len(values))]
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

im = plt.imshow(np.angle(H), origin='lower', aspect='auto')
values = np.linspace(np.min(np.angle(H)), np.max(np.angle(H)), 10)
colors = [ im.cmap(im.norm(value)) for value in values]
patches = [ mpatches.Patch(color=colors[i], label="Level {l}".format(l=values[i]) ) for i in range(len(values))]
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

plt.plot(nrExtractResources(dmrsIndices, np.abs(rxGrid)/np.abs(refGrid)))
plt.show()
plt.plot(nrExtractResources(dmrsIndices, np.angle(rxGrid/refGrid)))
plt.show()

# plt.plot(nrExtractResources(dmrsIndices, rxGrid))
# plt.show()
# plt.plot(nrExtractResources(dmrsIndices, rxGrid).real, nrExtractResources(dmrsIndices, rxGrid).imag, '.')
# plt.show()
# Out:
# 367.1316715038067
# nVar = 0.001434003838838476
# /tmp/ipykernel_343457/3019875934.py:41: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(nrExtractResources(dmrsIndices, np.abs(rxGrid)/np.abs(refGrid)))
# /tmp/ipykernel_343457/3019875934.py:43: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(nrExtractResources(dmrsIndices, np.angle(rxGrid/refGrid)))

# %%
pdsch_indices = nrPDSCHIndices(carrier, pdsch_cfg)
pdsch_eqed, csi = nrEqualizeMMSE(nrExtractResources(pdsch_indices, rxGrid), nrExtractResources(pdsch_indices, H), nVar)
fig, axs = plt.subplots(1, 1, figsize=(10, 10), facecolor='w', sharex=True, sharey=True)
samples = pdsch_eqed.ravel()
axs.plot(samples.real, samples.imag, '.')
axs.add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
axs.set_xticks([])
axs.set_yticks([])
axs.set_ylim([-1.5, 1.5])
axs.set_xlim([-1.5, 1.5])
axs.set_title('PDSCH')
# Out:
# Text(0.5, 1.0, 'PDSCH')

# %%
R = 658 / 1024   # MCS = 16, 64QAM-Table
mod = '16QAM'
A = nrTBS(mod, 1, 25 * 11, 12, R)
print(f'tbs = {A} bits, {A // 8} bytes')

demod_sym = nrSymbolDemodulate(pdsch_eqed, mod, 1, 'hard')
pdsch_bits = nrPDSCHDecode(np.expand_dims(pdsch_eqed, 0), [mod], detected_NID, 0)
print(pdsch_bits.shape)

# for i in range(100):
#     print(f'{i} {(pdsch_bits[0] < 0).astype(int)[i]}')
# np.savetxt('dummy_pdsch_bits.txt', demod_sym, delimiter = '\n', fmt = '%1d')
# np.savetxt('dummy_pdsch_bits.txt', (pdsch_bits < 0).astype(int), delimiter = '\n', fmt = '%1d')

# histogram of symbols before descrambling
plt.hist(np.packbits(demod_sym.reshape(demod_sym.shape[0]//4, 4), axis=1, bitorder='little'))
plt.title('PDSCH symbols before descrambling')
plt.show()
plt.hist(np.packbits((pdsch_bits[0,:] < 0).astype(int).reshape(demod_sym.shape[0]//4, 4), axis=1, bitorder='little'))
plt.title('PDSCH symbols after descrambling')
# Out:
# tbs = 8456 bits, 1057 bytes
# (1, 13200)
# Text(0.5, 1.0, 'PDSCH symbols after descrambling')

# %%
cbs_info = nrDLSCHInfo(A, R)
print(cbs_info)

raterec = nrRateRecoverLDPC(pdsch_bits[0], A, R = R, rv = 0, mod = mod, nLayers = 1)
dec_bits, numIter = nrLDPCDecode(raterec, cbs_info['BGN'], maxNumIter = 20, Algorithm = 'Normalized min-sum')
print(f'{dec_bits.shape[1]} blocks a {dec_bits.shape[0]} bits')

blk, blk_err = nrCodeBlockDesegmentLDPC(dec_bits, cbs_info['BGN'], A + cbs_info['L'])
print(f'crc: {int(blk_err)}')
out, tb_err = nrCRCDecode(blk, cbs_info['CRC'])
print(f'transport block CRC: {tb_err}')

rx_bytes = np.packbits(out[:, 0], axis = None, bitorder = 'big')
print(f'received {rx_bytes.shape[0]} bytes')
id_string = "".join([str(chr(character)) for character in rx_bytes[:50]])
print(id_string)
# Out:
# {'CRC': '24A', 'L': 24, 'BGN': 1, 'C': 2, 'Lcb': 24, 'F': 312, 'Zc': 208, 'K': 4576, 'N': 13728}
# 2 blocks a 4576 bits
# crc: 0
# transport block CRC: [0]
# received 1057 bytes
# no data available, subframe index = GENERIC

# %%
rxGrid_full = nrOFDMDemodulate(waveform = waveform[timingOffset:][:np.min((len(waveform), Nfft*1000))], nrb = carrier.NSizeGrid, scs = scsSSB, initialNSlot = 1, SampleRate=rxSampleRate, CyclicPrefixFraction=0.5)
rxGrid_full = rxGrid_full[:,13:]
rxGrid_full /= np.max((rxGrid_full.real.max(), rxGrid_full.imag.max()))
fig, axs = plt.subplots(7, 6, figsize=(20, 20), facecolor='w', sharex=True, sharey=True)
dummy_pdsch_bits = np.loadtxt('dummy_pdsch_bits.txt').astype(int)
dc_subcarriers = np.array([6 * 25 + 12 * 25 * i for i in range(11)])
dc_subcarriers = np.append(dc_subcarriers, (dc_subcarriers + 1, dc_subcarriers - 1)) # paint dc SCs +- 1 in different color
for i in range(24):
    sf_grid = rxGrid_full[:,14*i:14*(i+1)]
    dmrs_rx = nrExtractResources(dmrsIndices, sf_grid)
    carrier.NSlot = (i + 1) % 10
    dmrs_ideal_temp = nrPDSCHDMRS(pdsch_cfg, carrier)
    refGrid = np.zeros((carrier.NSizeGrid * 12, 14), 'complex')
    nrSetResources(dmrsIndices, refGrid, dmrs_ideal_temp)

    H, nVar = nrChannelEstimate(rxGrid = sf_grid, refGrid = np.sqrt(2)*refGrid)

    pdsch_eqed_temp, csi = nrEqualizeMMSE(nrExtractResources(pdsch_indices, sf_grid), nrExtractResources(pdsch_indices, H), nVar)
    # pdsch_eqed = sf_grid
    samples = pdsch_eqed.ravel()
    axs[i%7,i//7].plot(samples.real, samples.imag, '.')
    axs[i%7,i//7].plot(samples[dc_subcarriers].real, samples[dc_subcarriers].imag, '.')
    axs[i%7,i//7].add_patch(plt.Circle((0, 0), 1, color='red', fill=False, linewidth=1, linestyle=':'))
    axs[i%7,i//7].set_xticks([])
    axs[i%7,i//7].set_yticks([])
    axs[i%7,i//7].set_ylim([-1.5, 1.5])
    axs[i%7,i//7].set_xlim([-1.5, 1.5])

    pdsch_bits_temp = nrPDSCHDecode(np.expand_dims(pdsch_eqed_temp, 0), [mod], detected_NID, 0)

    np.array_equal((pdsch_bits_temp < 0).astype(int)[0], dummy_pdsch_bits)
    ber_descrambled = np.count_nonzero((pdsch_bits_temp < 0).astype(int)[0] != dummy_pdsch_bits)
    print(f'pdsch_bits BER = {ber_descrambled}')

    # raterec = nrRateRecoverLDPC((-1+2*dummy_pdsch_bits)*1e9, A, R = R, rv = 0, mod = mod, nLayers = 1)
    raterec_temp = nrRateRecoverLDPC(pdsch_bits_temp[0], A, R = R, rv = 0, mod = mod, nLayers = 1)
    dec_bits_temp, numIter = nrLDPCDecode(raterec_temp, cbs_info['BGN'], maxNumIter = 20, Algorithm = 'Normalized min-sum')
    print(f'{dec_bits.shape[1]} blocks a {dec_bits_temp.shape[0]} bits')

    blk, blk_err = nrCodeBlockDesegmentLDPC(dec_bits_temp, cbs_info['BGN'], A + cbs_info['L'])
    print(f'code block CRCs: {int(blk_err)}')
    out, tb_err = nrCRCDecode(blk, cbs_info['CRC'])
    print(f'transport block CRC: {tb_err[0]}')
    rx_bytes = np.packbits(out[:, 0], axis = None, bitorder = 'big')
    # print(f'received {rx_bytes.shape[0]} bytes')
    id_string = "".join([str(chr(character)) for character in rx_bytes[:50]])
    print(id_string)

    crc_result = 'ok' if tb_err == 0 else 'nok'
    if tb_err == 0:
        cbs_verify = nrCodeBlockSegmentLDPC(blk, 1)
        cws_verify = nrLDPCEncode(cbs_verify, 1)
        ratematched = nrRateMatchLDPC(cws_verify, 13200, 0, mod, 1)
        if i == 0:
            np.savetxt('dummy_pdsch_bits_new.txt', ratematched, fmt='%1d', delimiter = '\n')
        # enc_bits = nrPDSCH([ratemached], [mod], 1, 0, 0)
        ber = np.count_nonzero((pdsch_bits_temp < 0).astype(int)[0] != ratematched)
        print(f'BER = {ber}')
        # print(f'bit errors at {np.arange(13200)[(pdsch_bits_temp < 0).astype(int)[0] != ratematched]}')
        # for error_sym_idx in np.arange(13200)[(pdsch_bits_temp < 0).astype(int)[0] != ratematched]//4:
        #     print(f'error symbol {np.reshape((pdsch_bits_temp < 0).astype(int), (13200//4, 4))[error_sym_idx,:]} <-> {np.reshape((ratematched < 0).astype(int), (13200//4, 4))[error_sym_idx,:]}')

        axs[i%7,i//7].set_title(f'slot {i+1}, crc {crc_result}, BER {ber_descrambled}/{ber}')
    else:
        axs[i%7,i//7].set_title(f'slot {i+1}, crc {crc_result}, BER {ber_descrambled}/x')
# Out:
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 12
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 12
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 17
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 17
# pdsch_bits BER = 16
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 16
# pdsch_bits BER = 14
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 14
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 6
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 6
# pdsch_bits BER = 8
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 8
# pdsch_bits BER = 6
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 6
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 13
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 13
# pdsch_bits BER = 16
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 16
# pdsch_bits BER = 14
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 14
# pdsch_bits BER = 7
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 7
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 8
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 8
# pdsch_bits BER = 6580
# 2 blocks a 4576 bits
# nrCodeBlockDesegmentLDPC: crc error in segment 0
# nrCodeBlockDesegmentLDPC: crc error in segment 1
# code block CRCs: 1
# transport block CRC: 32509340
# n!¬´ ôà)1aDc2âê%÷EÀünõFk°°G]W;/Ô»?»¾üB\
# }
# pdsch_bits BER = 9
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 9
# pdsch_bits BER = 10
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 10
# pdsch_bits BER = 10
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 10
# pdsch_bits BER = 15
# 2 blocks a 4576 bits
# code block CRCs: 0
# transport block CRC: 0
# no data available, subframe index = GENERIC
# BER = 15
